# %%
#zip
A = [1, 2, 3]
B = 'abc'
for a, b in zip(A, B):
    print("a = ", a, "b = ", b)
# Out:
# a =  1 b =  a
# a =  2 b =  b
# a =  3 b =  c

# %%
pot = [[0,0], [0,0]]
coord = [(0,0), (0,1), (1,0), (1,1)]
inits = [1]*4

print("before:", pot)
for (i, j), val in zip(coord, inits):
    print("in a for loop", i, j, val)
    pot[i][j] = val

print("after:", pot)
# Out:
# before: [[0, 0], [0, 0]]
# in a for loop 0 0 1
# in a for loop 0 1 1
# in a for loop 1 0 1
# in a for loop 1 1 1
# after: [[1, 1], [1, 1]]

# %%
import numpy as np

def pot_origin(rx,ry,q):
    return q / np.sqrt(rx**2 + ry**2)

rs = [(1, 0), (0, 1), (2, 0)]
for r in rs:
    print(r)
    E = pot_origin(*r, 1)
   #E = pot_origin(r[0], r[1], 1)

    print(f"r = {r}, E = {E}")
# Out:
# (1, 0)
# r = (1, 0), E = 1.0
# (0, 1)
# r = (0, 1), E = 1.0
# (2, 0)
# r = (2, 0), E = 0.5

# %%
import numpy as np

def pot_2D(rx,ry,q=[1], q_pos=[(0,0)]):
    E = 0
    for qi, (x, y) in zip(q, q_pos):
        E += qi / np.sqrt((rx-x)**2 + (ry-y)**2)
    return E

coords = [(1,0), (0, 1), (1, 1), (2, 0)]

for pos in coords:
    E = pot_2D(0, 0, [1], [pos])
    print(f"charge 1 at {pos}: E")
# Out:
# charge 1 at (1, 0): E
# charge 1 at (0, 1): E
# charge 1 at (1, 1): E
# charge 1 at (2, 0): E

# %%
pot_2D(0, 0, [1]*4, coords)
# Out:
# 3.2071067811865475

# %%
import numpy as np
import matplotlib.pyplot as plt

def pot_2D(rx,ry,q=[1], q_pos=[(0,0)]):
    E = 0
    for qi, (x, y) in zip(q, q_pos):
        E += qi / np.sqrt((rx-x)**2 + (ry-y)**2)
    return E

fig = plt.figure()
ax = fig.add_subplot(aspect='equal')

Nplot = 200
X = np.linspace(-2, 2, Nplot)
Y = np.linspace(-2, 2, Nplot)

xx, yy = np.meshgrid(X, Y)

pot = pot_2D(xx, yy, q = [1, -1], q_pos = [(0.5, 0), (-0.5, 0)])
ax.contour(xx, yy, pot)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt

def pot_2D(rx,ry,q=[1], q_pos=[(0,0)]):
    E = 0
    for qi, (x, y) in zip(q, q_pos):
        E += qi / np.sqrt((rx-x)**2 + (ry-y)**2)
    return E

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')

Nplot = 200
X = np.linspace(-2, 2, Nplot)
Y = np.linspace(-2, 2, Nplot)

xx, yy = np.meshgrid(X, Y)

pot = pot_2D(xx, yy, q = [1, -1], q_pos = [(0.5, 0), (-0.5, 0)])
cont = ax.plot_surface(xx, yy, pot, cmap = 'bwr')
fig.colorbar(cont)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt

def pot_2D(rx,ry,q=[1], q_pos=[(0,0)]):
    E = 0
    for qi, (x, y) in zip(q, q_pos):
        E += qi / np.sqrt((rx-x)**2 + (ry-y)**2)
    return E

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')

Nplot = 200
X = np.linspace(-2, 2, Nplot)
Y = np.linspace(-2, 2, Nplot)

xx, yy = np.meshgrid(X, Y)

pot = pot_2D(xx, yy, q = [1, -1, 1, -1], q_pos = [(0.5, 0), (0, 0.5), (-0.5, 0), (0, -0.5)])
cont = ax.plot_surface(xx, yy, pot, cmap = 'bwr')
fig.colorbar(cont)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt

def pot_2D(rx,ry,q=[1], q_pos=[(0,0)]):
    E = 0
    for qi, (x, y) in zip(q, q_pos):
        E += qi / np.sqrt((rx-x)**2 + (ry-y)**2)
    return E

fig = plt.figure()
ax = fig.add_subplot(aspect = 'equal')

Nplot = 200
X = np.linspace(-2, 2, Nplot)
Y = np.linspace(-2, 2, Nplot)

xx, yy = np.meshgrid(X, Y)

pot = pot_2D(xx, yy, q = [1, -1, 1, -1], q_pos = [(0.5, 0), (0, 0.5), (-0.5, 0), (0, -0.5)])
cont = ax.plot_surface(xx, yy, pot, cmap = 'bwr')
fig.colorbar(cont)

plt.show

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(121) # 1행 2열 중 1번째
ax2 = fig.add_subplot(122) # 1행 2열 중 2번째

X = np.linspace(1, 1.1, 101)
X2 = np.linspace(100, 110, 101)
# +e at x=1. -e at x=-1 : 1/(x-1) - 1/(x+1)
Y = 1/(X-1) - 1/(X+1)
Y2 = 1/(X2-1) - 1/(X2+1)

ax.scatter(X[::10], Y[::10], label='dipole') # 점이 너무 많이 출력될 때, 슬라이싱을 이용하여 개수를 조절
ax2.scatter(X2[::10], Y2[::10], label='dipole')

ax.plot(X, 1/(X-1), label='$1/(X-1)$')
ax2.plot(X2, 1/(X2-1), label='$1/(X-1)$')
ax.plot(X, 1/X**2, label='$1/X^2$')
ax2.plot(X2, 1/X2**2, label='$1/X^2$')

ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax2.set_xlabel('$x$')
ax2.set_ylabel('$y$')
ax.legend()
ax2.legend()

plt.show()
# Out:
# <ipython-input-22-1f6e6d6c46f2>:11: RuntimeWarning: divide by zero encountered in divide
#   Y = 1/(X-1) - 1/(X+1)
# <ipython-input-22-1f6e6d6c46f2>:17: RuntimeWarning: divide by zero encountered in divide
#   ax.plot(X, 1/(X-1), label='$1/(X-1)$')

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_dipole(ax, X):
    Y = 1/(X-1) - 1/(X+1)
    Y2 = 1/X**2
    ax.scatter(X[::10], Y[::10], label='dipole')
    ax.plot(X, 1/(X-1), label='$1/(X-1)$')
    ax.plot(X, 1/X**2, label='$1/X^2$')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.legend()

fig = plt.figure()

ax = fig.add_subplot(221)  # 2행 2열 중 1번째
ax2 = fig.add_subplot(222) # 2행 2열 중 2번째
ax3 = fig.add_subplot(223) # 2행 2열 중 3번째
ax4 = fig.add_subplot(224) # 2행 2열 중 4번째


X = np.linspace(1, 1.1, 101)
X2 = np.linspace(100, 110, 101)
X3 = np.linspace(-2, -1, 101)
X4 = np.linspace(-110, 10, 101)

plot_dipole(ax, X)
plot_dipole(ax2, X2)
plot_dipole(ax3, X3)
plot_dipole(ax4, X4)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-28-aef80a1169cb>:5: RuntimeWarning: divide by zero encountered in divide
#   Y = 1/(X-1) - 1/(X+1)
# <ipython-input-28-aef80a1169cb>:8: RuntimeWarning: divide by zero encountered in divide
#   ax.plot(X, 1/(X-1), label='$1/(X-1)$')

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(221)
ax2 = fig.add_subplot(223)
ax3 = fig.add_subplot(122)

X = np.linspace(0, 10, 101)
ax.plot(X, X**2, color='mediumslateblue', label='$1/X^2$', alpha = 0.5) #alpha는 투명도, 그래프가 겹칠때 사용
ax2.plot(X, 1/X, color='mediumaquamarine', label='$1/X$')
ax3.plot(X, 1/X**3, color='mediumturquoise', label='$1/X^3$')

ax.legend()
ax2.legend()
ax3.legend()

ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax2.set_xlabel('$x$')
ax2.set_ylabel('$y$')
ax3.set_xlabel('$x$')
ax3.set_ylabel('$y$')


plt.tight_layout()
plt.show()
# Out:
# <ipython-input-44-176e5e1bb94f>:11: RuntimeWarning: divide by zero encountered in divide
#   ax2.plot(X, 1/X, color='mediumaquamarine', label='$1/X$')
# <ipython-input-44-176e5e1bb94f>:12: RuntimeWarning: divide by zero encountered in divide
#   ax3.plot(X, 1/X**3, color='mediumturquoise', label='$1/X^3$')

# %%
import matplotlib.pyplot as plt
import numpy as np

w = 3
Y, X = np.mgrid[-w:w:100j, -w:w:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U**2 + V**2)

fig, axs = plt.subplots(3, 2, figsize=(7, 9), height_ratios=[1, 1, 2])
axs = axs.flat

#  Varying density along a streamline
axs[0].streamplot(X, Y, U, V, density=[0.5, 1])
axs[0].set_title('Varying Density')

# Varying color along a streamline
strm = axs[1].streamplot(X, Y, U, V, color=U, linewidth=2, cmap='autumn')
fig.colorbar(strm.lines)
axs[1].set_title('Varying Color')

#  Varying line width along a streamline
lw = 5*speed / speed.max()
axs[2].streamplot(X, Y, U, V, density=0.6, color='k', linewidth=lw)
axs[2].set_title('Varying Line Width')

# Controlling the starting points of the streamlines
seed_points = np.array([[-2, -1, 0, 1, 2, -1], [-2, -1,  0, 1, 2, 2]])

strm = axs[3].streamplot(X, Y, U, V, color=U, linewidth=2,
                         cmap='autumn', start_points=seed_points.T)
fig.colorbar(strm.lines)
axs[3].set_title('Controlling Starting Points')

# Displaying the starting points with blue symbols.
axs[3].plot(seed_points[0], seed_points[1], 'bo')
axs[3].set(xlim=(-w, w), ylim=(-w, w))

# Create a mask
mask = np.zeros(U.shape, dtype=bool)
mask[40:60, 40:60] = True
U[:20, :20] = np.nan
U = np.ma.array(U, mask=mask)

axs[4].streamplot(X, Y, U, V, color='r')
axs[4].set_title('Streamplot with Masking')

axs[4].imshow(~mask, extent=(-w, w, -w, w), alpha=0.5, cmap='gray',
              aspect='auto')
axs[4].set_aspect('equal')

axs[5].streamplot(X, Y, U, V, broken_streamlines=False)
axs[5].set_title('Streamplot with unbroken streamlines')

plt.tight_layout()
plt.show()
