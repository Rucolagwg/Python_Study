# %%
def add(a, b, show = False):
    if show:
      print('a =', a, 'b =', b)
    return a + b

a = 21
b = 43
print( add(a, b, False) )
add(2, 4) #마지막에 써있는 것은 한번 출력. 그러나 앞에 쓴 것은 print를 쓰지 않으면 출력하지 않는다.
# Out:
# 64
# 6

# %%
def add(a, b, show = True):
    if show:
      print('a =', a, 'b =', b)
    return a + b

a = 21
b = 43
print( add(a, b) )
add(2, 4) #마지막에 써있는 것은 한번 출력. 그러나 앞에 쓴 것은 print를 쓰지 않으면 출력하지 않는다.
# Out:
# a = 21 b = 43
# 64
# a = 2 b = 4
# 6

# %%
def f(x, start=0):
    sum = 0
    for i in range(start, x):
        sum += i*i
    return sum

f(4, start=2)
# Out:
# 13

# %%
def f(x, start=0):
    sum = 0
    for i in range(start, x):
        sum += i*i
    return sum

result = [f(i) for i in range(1, 5)]
print('result')
# Out:
# result

# %%
import numpy as np

# %%
np.array(range(3))
# Out:
# array([0, 1, 2])

# %%
range(3)
# Out:
# range(0, 3)

# %%
import numpy as np
list(range(3))
# Out:
# [0, 1, 2]

# %%
import numpy as np
print( np.array(range(5))**2)
print( np.sum(np.array(range(5))**2))
# Out:
# [ 0  1  4  9 16]
# 30

# %%
np.sum([12,46,64])
# Out:
# 122

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make a stream function:
X, Y = np.meshgrid(np.linspace(-3, 3, 256), np.linspace(-3, 3, 256))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)
# make U and V out of the streamfunction:
V = np.diff(Z[1:, :], axis=1)
U = -np.diff(Z[:, 1:], axis=0)

# plot:
fig, ax = plt.subplots()

ax.streamplot(X[1:, 1:], Y[1:, 1:], U, V)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data: correlated + noise
np.random.seed(1)
x = np.random.randn(5000)
y = 1.2 * x + np.random.randn(5000) / 3

# plot:
fig, ax = plt.subplots()

ax.hist2d(x, y, bins=(np.arange(-3, 3, 0.1), np.arange(-3, 3, 0.1)))

ax.set(xlim=(-2, 2), ylim=(-3, 3))

plt.show()

# %% [markdown]
# 연습문제(1~8)

# %%
def f(x, y):
    if x == y:
        print("error")
        return
    return (x+y)/(x-y)

f(1,3)
# Out:
# -2.0

# %%
def f(n, m):
    if n > m:
        Max = n
    elif m > n:
        Max = m
    else:
        print("Same")
        return
    return Max

f(4,4)
# Out:
# Same

# %%
def f(n, m):
    if m >= n:
        return tot
    else:
        print("Error")
        return

f(1,4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-dc5586f57c2e> in <cell line: 8>()
#       6         return
#       7
# ----> 8 f(1,4)
#
# <ipython-input-25-dc5586f57c2e> in f(n, m)
#       1 def f(n, m):
#       2     if m >= n:
# ----> 3         return tot
#       4     else:
#       5         print("Error")
#
# NameError: name 'tot' is not defined

# %%
def f(n, m):
    sum = 0
    if m >= n:
        for i in range(n+1, m):
            sum += i
        return sum

    else:
        print("Error");
        return

f(2,5)
# Out:
# 7

# %%
def f(m):
    a = 1
    fac = 1
    if m > 0:
        for i in range(1, m+1):
            fac *= i
        return fac

    else:
        print("Error");
        return

f(5)
# Out:
# 120

# %%
def f(m):
    sum = 0
    if m > 0:
        for i in range(0, m+1):
            sum += i
        return sum

    else:
        print("Error");
        return

f(4)
# Out:
# 10

# %%
def f(n):
    sum = 0
    if n > 0:
        for i in range(1, 1001):
            if (i % n == 0):
                sum += 1
        return sum

    else:
        print("Error");
        return

f(100)
# Out:
# 10

# %%
def f(n, m, l):
    sum = 0
    for i in range(n, m+1):
            if (i % l == 0):
                sum += i
    return sum

f(1, 50, 5)
# Out:
# 275
